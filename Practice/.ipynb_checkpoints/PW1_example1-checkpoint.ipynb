# %% [markdown]
# # Практическая работа №1.1: мониторинг городского климата

# %%
import pandas as pd
from matplotlib import pyplot as plt
import meteo_utils

# %% [markdown]
# ## Чтение данных из архива RP5, первичный просмотр

# %%
path_urb = r'PW1_data\Moscow_rp5\27605.31.10.2012.21.01.2024.1.0.0.ru.utf8.00000000.xls'
path_rur = r'PW1_data\Moscow_rp5\27518.31.10.2012.21.01.2024.1.0.0.ru.utf8.00000000.xls'


df_urb = meteo_utils.read_rp5 (path_urb)
df_rur = meteo_utils.read_rp5 (path_rur)

df_urb['T'].plot(color = 'red')
df_rur['T'].plot(color = 'blue')
plt.xlim([pd.Timestamp(2023,8,1),pd.Timestamp(2023,9,1)])
plt.ylim([0, 30])
# Out:
# (0.0, 30.0)

# %% [markdown]
# ## Объединение данных двух станций в одни DataFrame

# %%
df_merged = df_urb.merge(df_rur, how = 'outer', on='local time', suffixes=('_urb', '_rur'))
df_merged['delta_T'] = df_merged['T_urb'] - df_merged['T_rur']

display(df_merged.head())

df_resampled = df_merged.resample('3h').asfreq()

df_cropped = df_resampled[(df_resampled.index > pd.Timestamp (2023, 8, 1))
                        & (df_resampled.index < pd.Timestamp (2023, 9, 1))]


df_cropped['delta_T'].plot()
# Out:
#                     Местное время в Москве (центр, Балчуг)  T_urb  Po_urb  \
# local time
# 2024-01-21 21:00:00                       21.01.2024 21:00   -9.4   763.6
# 2024-01-21 18:00:00                       21.01.2024 18:00   -9.9   762.4
# 2024-01-21 15:00:00                       21.01.2024 15:00   -9.5   761.0
# 2024-01-21 12:00:00                       21.01.2024 12:00  -10.1   759.9
# 2024-01-21 09:00:00                       21.01.2024 09:00  -11.1   758.5
#
#                      P_urb  Pa_urb  U_urb  \
# local time
# 2024-01-21 21:00:00  776.0     NaN   77.0
# 2024-01-21 18:00:00  774.8     NaN   76.0
# 2024-01-21 15:00:00  773.3     NaN   70.0
# 2024-01-21 12:00:00  772.3     NaN   71.0
# 2024-01-21 09:00:00  770.8     NaN   74.0
#
#                                                    DD_urb  Ff_urb  ff10_urb  \
# local time
# 2024-01-21 21:00:00         Ветер, дующий с северо-запада     2.0       NaN
# 2024-01-21 18:00:00  Ветер, дующий с западо-северо-запада     1.0       NaN
# 2024-01-21 15:00:00  Ветер, дующий с западо-северо-запада     1.0       NaN
# 2024-01-21 12:00:00                Ветер, дующий с запада     1.0       NaN
# 2024-01-21 09:00:00         Ветер, дующий с северо-запада     1.0       NaN
#
#                      ff3_urb  ... Ch_rur VV_rur Td_rur      RRR_rur  tR_rur  \
# local time                    ...
# 2024-01-21 21:00:00      NaN  ...    NaN     14  -13.9  Осадков нет    12.0
# 2024-01-21 18:00:00      NaN  ...    NaN     17  -17.5  Осадков нет    12.0
# 2024-01-21 15:00:00      NaN  ...    NaN    NaN    NaN          NaN     NaN
# 2024-01-21 12:00:00      NaN  ...    NaN     13  -13.1          NaN     NaN
# 2024-01-21 09:00:00      NaN  ...    NaN     14  -21.9          0.1    12.0
#
#                      E_rur Tg_rur  \
# local time
# 2024-01-21 21:00:00    NaN    NaN
# 2024-01-21 18:00:00    NaN    NaN
# 2024-01-21 15:00:00    NaN    NaN
# 2024-01-21 12:00:00    NaN    NaN
# 2024-01-21 09:00:00    NaN    NaN
#
#                                                                 E'_rur  \
# local time
# 2024-01-21 21:00:00                                                NaN
# 2024-01-21 18:00:00                                                NaN
# 2024-01-21 15:00:00                                                NaN
# 2024-01-21 12:00:00                                                NaN
# 2024-01-21 09:00:00  Ровный слой сухого рассыпчатого снега покрывае...
#
#                     sss_rur delta_T
# local time
# 2024-01-21 21:00:00     NaN     3.6
# 2024-01-21 18:00:00     NaN     6.6
# 2024-01-21 15:00:00     NaN     NaN
# 2024-01-21 12:00:00     NaN     1.8
# 2024-01-21 09:00:00      31     9.2
#
# [5 rows x 59 columns]
# <AxesSubplot:xlabel='local time'>

# %% [markdown]
# ## Чтение данных из архива "Погода и климат", первичный просмотр

# %%
path = r'PW1_data\Moscow_weaclim\27605\'

df = meteo_utils.read_weaclim_html (path)
display(df.columns)
display(df.head())
df['Т(С)'].astype('float').plot()
# Out:
# '    <meta name="description" content="Архив фактической погоды в Москве (Балчуг) (атмосферное давление, температура воздуха, влажность воздуха, направление и скорость ветра, атмосферные явления, осадки) за ноябрь 2023 года.">\n'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14340/3002125892.py in <module>
#       1 path = r'PW1_data\Moscow_weaclim\27605\27605_202311.html'
#       2
# ----> 3 df = meteo_utils.read_weaclim_html (path)
#       4 display(df.columns)
#       5 display(df.head())
#
# D:\! Work\!git\Lectures\Urban-climate-modelling4HSE\Practice\meteo_utils.py in read_weaclim_html(path)
#      18     file.close()
#      19
# ---> 20     year_str = re.search('за (.*) года', line).group(1).split()[1]
#      21
#      22     df0 = pd.read_html(path)[0]
#
# NameError: name 're' is not defined
