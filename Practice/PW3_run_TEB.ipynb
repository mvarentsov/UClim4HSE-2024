# %% [markdown]
# <a href="https://colab.research.google.com/github/mvarentsov/Urban-climate-modelling4HSE/blob/main/Practice/PW3_run_TEB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Скачивание модели из репозитория
# Остророжно, директорая удаляется и создается заново!

# %%
import os

# %cd /content/drive/MyDrive/TEB4HSE/
if os.path.isdir ('TEB_open_source_v3_sfx8.1_orig_namelist'):
  # %rm -r 'TEB_open_source_v3_sfx8.1_orig_namelist'

# !git clone https://github.com/mkolennikova/TEB_open_source_v3_sfx8.1_orig_namelist.git
# Out:
# /content/drive/MyDrive/TEB4HSE
# Cloning into 'TEB_open_source_v3_sfx8.1_orig_namelist'...
# remote: Enumerating objects: 288, done.
# remote: Counting objects: 100% (288/288), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 288 (delta 89), reused 275 (delta 76), pack-reused 0
# Receiving objects: 100% (288/288), 4.86 MiB | 8.24 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# Updating files: 100% (238/238), done.
# /content/drive/MyDrive/TEB4HSE/TEB_open_source_v3_sfx8.1_orig_namelist

# %% [markdown]
# Компиляция модели

# %%
# %cd '/content/drive/MyDrive/TEB4HSE/TEB_open_source_v3_sfx8.1_orig_namelist'
# !make clean
# !make all
# Out:
# rm -f
# ...

# %% [markdown]
# #### Запуск исполняемого файла модели

# %%
# !./tester.exe
# Out:
#     1/ 8759
#     2/ 8759
#     3/ 8759
#     4/ 8759
#     5/ 8759
#     6/ 8759
#     7/ 8759
#     8/ 8759
#     9/ 8759
#    10/ 8759
#    11/ 8759
#    12/ 8759
#    13/ 8759
#    14/ 8759
#    15/ 8759
#    16/ 8759
#    17/ 8759
#    18/ 8759
#    19/ 8759
#    20/ 8759
#    21/ 8759
#    22/ 8759
#    23/ 8759
#    24/ 8759
#    25/ 8759
#    26/ 8759
#    27/ 8759
#    28/ 8759
#    29/ 8759
#    30/ 8759
#    31/ 8759
#    32/ 8759
#    33/ 8759
#    34/ 8759
#    35/ 8759
#    36/ 8759
#    37/ 8759
#    38/ 8759
#    39/ 8759
#    40/ 8759
#    41/ 8759
#    42/ 8759
#    43/ 8759
#    44/ 8759
#    45/ 8759
#    46/ 8759
#    47/ 8759
#    48/ 8759
#    49/ 8759
#    50/ 8759
#    51/ 8759
#    52/ 8759
#    53/ 8759
#    54/ 8759
#    55/ 8759
#    56/ 8759
#    57/ 8759
#    58/ 8759
#    59/ 8759
#    60/ 8759
#    61/ 8759
#    62/ 8759
#    63/ 8759
#    64/ 8759
#    65/ 8759
#    66/ 8759
#    67/ 8759
#    68/ 8759
#    69/ 8759
#    70/ 8759
#    71/ 8759
# ...
